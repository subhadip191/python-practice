# %% [markdown]
# # Strings

# %% [markdown]
# ### Strings are sequence of Characters
#
# ### In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %% [markdown]
# ## Creating Stings

# %%
s = 'hello'
s = "hello"
# multiline strings
s = '''hello'''
s = """hello"""
s = str('hello')
print(s)
# Out:
# hello

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %% [markdown]
# ## Accessing Substrings from a String

# %%
# Positive Indexing
s = 'hello world'
print(s[0])
print(s[4])
# Out:
# h
# o

# %%
print(s[20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(s[20])
#
# IndexError: string index out of range

# %%
# Negative Indexing
s = 'hello world'
print(s[-3])
# Out:
# r

# %%
# Slicing
# [start, stop, step]

print(s[::-1])

print(s[:2:])

print(s[6:0:-2])
# Out:
# dlrow olleh
# he
# wol

# %% [markdown]
# ## Editing and Deleting in Strings

# %%
# Python strings are immutable

s = 'hello world'
s[0] = 'H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 # Python strings are immutable
#       3 s = 'hello world'
# ----> 4 s[0] = 'H'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 s = 'hello world'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
s = 'hello world'
del s[-1:-5:2]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s)
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# ## Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
print('hello' + ' ' + 'world')
# Out:
# hello world

# %%
print('hiii '*15)
# Out:
# hiii hiii hiii hiii hiii hiii hiii hiii hiii hiii hiii hiii hiii hiii hiii

# %%
'hmm' != 'hmm'
# Out:
# False

# %%
'hmm' == 'hmm'
# Out:
# True

# %%
# lexiographically
'k' > 'a'
# Out:
# True

# %%
'A' > 'a'
# Out:
# False

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
not 'hello'
# Out:
# False

# %%
for i in 'hello':
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
for i in 'Subhadip':
  print('Maity')
# Out:
# Maity
# Maity
# Maity
# Maity
# Maity
# Maity
# Maity
# Maity

# %%
's' in 'Subhadip'
# Out:
# False

# %%
'S' in 'Subhadip'
# Out:
# True

# %%
'Sa' in 'Subhadip'
# Out:
# False

# %% [markdown]
# ## Common Functions
# - len
# - max
# - min
# - sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world',reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# ## Capitalize/Title/Upper/Lower/Swapcase

# %%
s = 'hello world'
print(s.capitalize())
print(s)
# Out:
# Hello world
# hello world

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
'Hello Wolrd'.lower()
# Out:
# 'hello wolrd'

# %%
'HeLlO WorLD'.swapcase()
# Out:
# 'hElLo wORld'

# %% [markdown]
# ## Count/Find/Index

# %%
'My name is Subhadip'.count('i')
# Out:
# 2

# %%
'I am a student in camp x'.find('x')
# Out:
# 23

# %%
'I am a student'.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 'I am a student'.index('x')
#
# ValueError: substring not found

# %% [markdown]
# ## endswith/startswith

# %%
st = 'My name is Subhadip'
st.endswith('my')
# Out:
# False

# %%
st.startswith('my')
# Out:
# False

# %%
st.startswith('My')
# Out:
# True

# %% [markdown]
# ## format

# %%
name = 'Subhadip'
gender = 'male'

'Hi my name is {1} and I am a {0}'.format(gender,name)
# Out:
# 'Hi my name is Subhadip and I am a male'

# %% [markdown]
# ## isalnum/ isalpha/ isdigit/ isidentifier

# %%
'sdm1234%'.isalnum()
# Out:
# False

# %%
'sdM'.isalpha()
# Out:
# True

# %%
'123abc'.isdigit()
# Out:
# False

# %%
'first-name'.isidentifier()
# Out:
# False

# %% [markdown]
# ## Split/Join

# %%
'hi my name is sdm'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'sdm']

# %%
" ".join(['hi', 'my', 'name', 'is', 'sdm'])
# Out:
# 'hi my name is sdm'

# %% [markdown]
# ## Replace

# %%
'hi my name is sdm'.replace('i','L')
# Out:
# 'hL my name Ls sdm'

# %% [markdown]
# ## Strip

# %%
'sdm                           '.strip()
# Out:
# 'sdm'

# %% [markdown]
# ## Example Programs

# %%
# Find the length of a given string without using the len() function

s = input('enter the string ')

counter = 0

for i in s:
  counter += 1

print('length of string is',counter)
# Out:
# length of string is 14

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the email')
term = input('what would like to search for')

counter = 0
for i in s:
  if i == term:
    counter += 1

print('frequency',counter)
# Out:
# frequency 2

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

result = ''

for i in s:
  if i != term:
    result = result + i

print(result)
# Out:
# 'ello ow are you'

# %%
# Write a program that can check whether a given string is palindrome or not.
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')
# Out:
# Palindrome

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string')
L = []
temp = ''
count = 0
for i in s:

  if i != ' ':
    temp = temp + i
    count += 1
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
print(count)
# Out:
# ['Hello', 'my', 'name', 'is', 'Subhadip', 'Maity']
# 26

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# I Am A Student

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# 123456
# <class 'str'>
